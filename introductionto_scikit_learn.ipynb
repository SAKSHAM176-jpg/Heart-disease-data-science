# %% [markdown]
# ## 2.Choosing the right estimator/algorithm for your problem
# 1. sklearn refers to machine learning models ,algorithms as estimators.
# 2. classification problem-predicting a category(heart disease or not)
# 3. sometimes you'll see clf (short for classifier) uesd as a classification estimator
# 4. regression prblem - predicting a number (selling price of a car)

# %%
# Numerical computing
import numpy as np

# Data handling
import pandas as pd

# Plotting
import matplotlib.pyplot as plt
#get california housing datasets
from sklearn.datasets import fetch_california_housing
housing =fetch_california_housing()
housing
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]], shape=(20640, 8)),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
# ...

# %%
housing_df=pd.DataFrame(housing["data"],columns=housing["feature_names"])
housing_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
housing_df["target"]=housing["target"]
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
housing_df=housing_df.drop("MedHouseVal",axis=1)
housing_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 housing_df=housing_df.drop("MedHouseVal",axis=1)
#       2 housing_df
#
# File ~\OneDrive\Desktop\sample_project_1\env\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
from sklearn.model_selection import train_test_split
#import algorithm
from sklearn.linear_model import Ridge
#setup random seed
np.random.seed(42)
#create data
x=housing_df.drop("target",axis=1)
y=housing_df["target"]
#split into train and test sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#Instantiate and fir the model 
model=Ridge()
model.fit(x_train,y_train)
#check the score of models
model.score(x_test,y_test)

# %% [markdown]
# what if ridge is not working or the score didn't fit our needs?
# we will try different models

# %%
# importing the randomforestreegressor model class from the ensemble module
from sklearn.ensemble import RandomForestRegressor
np.random.seed(42)
x=housing_df.drop("target",axis=1)
y=housing_df["target"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#Instantiate and fir the model 
model=RandomForestRegressor()
model.fit(x_train,y_train)
#check the score of models
model.score(x_test,y_test)

# %% [markdown]
# ## 2.2 Picking a machine learning model for a classificaton problem

# %%
heart_disease=pd.read_csv("csv_files/heart-disease.csv")

# %%
#import the linear svc estimator
from sklearn.svm import LinearSVC
#setup  random seed
np.random.seed(42)
# make the data
x=heart_disease.drop("target",axis=1)
y=heart_disease["target"]
#split the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#instantiate linearsvc
clf=LinearSVC()
clf.fit(x_train,y_train)
#evaluate the linearsvc
clf.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       7 y=heart_disease["target"]
#       8 #split the data
# ----> 9 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#      10 #instantiate linearsvc
#      11 clf=LinearSVC()
#
# NameError: name 'train_test_split' is not defined

# %%
heart_disease["target"].value_counts()

# %%
#import the randomforest classifiers estimator
from sklearn.ensemble import RandomForestClassifier
#setup  random seed
np.random.seed(42)
# make the data
x=heart_disease.drop("target",axis=1)
y=heart_disease["target"]
#split the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#instantiate linearsvc
clf=RandomForestClassifier(n_estimators=100)
clf.fit(x_train,y_train)
#evaluate the linearsvc
clf.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       7 y=heart_disease["target"]
#       8 #split the data
# ----> 9 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#      10 #instantiate linearsvc
#      11 clf=RandomForestClassifier(n_estimators=100)
#
# NameError: name 'train_test_split' is not defined

# %% [markdown]
# ### if you have structured data,used ensemble methods and for unstructured use deep learning or transfer learning

# %% [markdown]
# ## 3. Fit the model/algorthim on our data and use it to make predictions
# ## 3.1 Fitting the model to the data

# %%
#import the randomforest classifiers estimator
from sklearn.ensemble import RandomForestClassifier
#setup  random seed
np.random.seed(42)
# make the data
x=heart_disease.drop("target",axis=1)
y=heart_disease["target"]
#split the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#instantiate linearsvc
clf=RandomForestClassifier(n_estimators=100)
#FIT THE MODEL TO THE DATA
clf.fit(x_train,y_train)
#evaluate the linearsvc
clf.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       7 y=heart_disease["target"]
#       8 #split the data
# ----> 9 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#      10 #instantiate linearsvc
#      11 clf=RandomForestClassifier(n_estimators=100)
#
# NameError: name 'train_test_split' is not defined

# %% [markdown]
# ##
#
# 3.2 Make predictions using a machine learning models
# two methods:
# 1. predict()
# 2. predict_prona()

# %%
#Use a trained model to make prediction
clf.predict(np.array([2,42,42,44,1])) # this is not gonna work
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #Use a trained model to make prediction
# ----> 2 clf.predict(np.array([2,42,42,44,1]))
#
# NameError: name 'clf' is not defined

# %%
clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 clf.predict(x_test)
#
# NameError: name 'clf' is not defined

# %%
y_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 y_test
#
# NameError: name 'y_test' is not defined

# %%
y_preds=clf.predict(x_test)
np.mean(y_preds==y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 y_preds=clf.predict(x_test)
#       2 np.mean(y_preds==y_test)
#
# NameError: name 'clf' is not defined

# %%
clf.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 clf.score(x_test,y_test)
#
# NameError: name 'clf' is not defined

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_preds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy_score(y_test,y_preds)
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# # make prediction with pridict_prona()

# %%
#predict_proba() returns probabilies of a classification label 
clf.predict_proba(x_test[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 #predict_proba() returns probabilies of a classification label
# ----> 2 clf.predict_proba(x_test[:5])
#
# NameError: name 'clf' is not defined

# %%
#let's predict() on the same data
clf.predict(x_test[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 #let's predict() on the same data
# ----> 2 clf.predict(x_test[:5])
#
# NameError: name 'clf' is not defined

# %%
print("hello")
# Out:
# hello

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor 
np.random.seed(42)
x=housing_df.drop("target",axis=1)
y=housing_df["target"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

model=RandomForestRegressor()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       3 x=housing_df.drop("target",axis=1)
#       4 y=housing_df["target"]
# ----> 5 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#       7 model=RandomForestRegressor()
#       8 model.fit(x_train,y_train)
#
# NameError: name 'train_test_split' is not defined

# %%
y_preds[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 y_preds[:10]
#
# NameError: name 'y_preds' is not defined

# %%
print("hello")
# Out:
# hello

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
np.random.seed(42)
#create the data
x=housing_df.drop("target",axis=1)
y=housing_df["target"]
# split into training sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#create model instance
model=RandomForestRegressor()
#fit the data
model.fit(x_train,y_train)
# make predictions
y_preds=model.predict(x_test)

# %%
y_preds[:10]
# Out:
# array([0.4939   , 0.75494  , 4.9285964, 2.54024  , 2.33176  , 1.6602201,
#        2.3431   , 1.66311  , 2.47489  , 4.8344779])

# %%
np.array(y_test[:10])
# Out:
# array([0.477  , 0.458  , 5.00001, 2.186  , 2.78   , 1.587  , 1.982  ,
#        1.575  , 3.4    , 4.466  ])

# %%
#campare the prediction to the truth
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_preds)
# Out:
# 0.32656738464147306

# %% [markdown]
# ## 4. Evaluating a machine learnling model
#
#  three ways
#  1. Estimator's built in 'score' method
#  2.the scoring parameters
#  3.problem specific metrics functions

# %% [markdown]
# ## 4.1 using 'score'

# %%
#import the randomforest classifiers estimator
from sklearn.ensemble import RandomForestClassifier
#setup  random seed
np.random.seed(42)
# make the data
x=heart_disease.drop("target",axis=1)
y=heart_disease["target"]
#split the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#instantiate linearsvc
clf=RandomForestClassifier(n_estimators=100)
#FIT THE MODEL TO THE DATA
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
clf.score(x_train,y_train)
# Out:
# 1.0

# %%
clf.score(x_test,y_test)
# Out:
# 0.8524590163934426

# %%
# the default score() evaluation metric is r squared for the regression algorithms 
#highest =1 and lowest  is 0

# %% [markdown]
# ### 4.2 using scoring parameters

# %%
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import RandomForestClassifier
#setup  random seed
np.random.seed(42)
# make the data
x=heart_disease.drop("target",axis=1)
y=heart_disease["target"]
#split the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#instantiate linearsvc
clf=RandomForestClassifier(n_estimators=100)
#FIT THE MODEL TO THE DATA
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
clf.score(x_test,y_test)
# Out:
# 0.8524590163934426

# %%
cross_val_score(clf,x,y, cv=5)
# Out:
# array([0.81967213, 0.86885246, 0.81967213, 0.78333333, 0.76666667])

# %%
np.random.seed(42)
#single training and test split score
clf_single_score=clf.score(x_test,y_test)
#take the mean of 5 fold cross validation score
clf_cross_val_score=np.mean(cross_val_score(clf,x,y,cv=5))
#compare the two
clf_single_score,clf_cross_val_score
# Out:
# (0.8524590163934426, np.float64(0.8248087431693989))

# %%
#default scoring patameter of classifier = mean accuracy
clf.score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 #default scoring patameter of classifier = mean accuracy
# ----> 2 clf.score()
#
# TypeError: ClassifierMixin.score() missing 2 required positional arguments: 'X' and 'y'

# %%
# scoring parameter set to none by default
cross_val_score(clf,x,y,cv=5,scoring=None)
# Out:
# array([0.78688525, 0.86885246, 0.80327869, 0.78333333, 0.76666667])

# %% [markdown]
# ### 4.2.1 classification model evaluation metrics
# 1. accuacy
# 2. area under roc curve
# 3.  confusin matrix
# 4. .Classification report
# #### accuacy

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

np.random.seed(42)
x=heart_disease.drop("target",axis=1)
y=heart_disease["target"]
clf=RandomForestClassifier()
cross_val_score=cross_val_score(clf,x,y,cv=5)

# %%
np.mean(cross_val_score)
# Out:
# np.float64(0.8248087431693989)

# %%
print(f"heart disease classifier cross-validated Accuracy: {np.mean(cross_val_score)*100:.2f}%")
# Out:
# heart disease classifier cross-validated Accuracy: 82.48%

# %% [markdown]
# #### area under the receivser operating characterstics curve(AUC/ROC)**
# ROC curve are a comparison of model's true positive rate (tpr) verse a model fale positive rate (fpr)
#
# 1. true positive=model predicts 1  when truth is 1
# 2. false positive=model predicts 1  when truth is 0
# 3. true negative=model predicts 0  when truth is 0
# 4. false negative=model predicts 0  when truth is 1

# %%
#create x and y
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
from sklearn.metrics import roc_curve
clf.fit(x_train,y_train)

y_probs=clf.predict_proba(x_test)
y_probs
# Out:
# array([[0.51, 0.49],
#        [0.17, 0.83],
#        [0.51, 0.49],
#        [0.72, 0.28],
#        [0.43, 0.57],
#        [0.12, 0.88],
#        [0.3 , 0.7 ],
#        [0.97, 0.03],
#        [0.15, 0.85],
#        [0.4 , 0.6 ],
#        [0.13, 0.87],
#        [0.29, 0.71],
#        [0.04, 0.96],
#        [0.53, 0.47],
#        [0.15, 0.85],
#        [0.89, 0.11],
#        [0.19, 0.81],
#        [0.34, 0.66],
#        [0.94, 0.06],
#        [0.92, 0.08],
#        [0.05, 0.95],
#        [0.14, 0.86],
#        [0.01, 0.99],
#        [0.19, 0.81],
#        [0.95, 0.05],
#        [0.64, 0.36],
#        [0.15, 0.85],
#        [0.84, 0.16],
#        [0.29, 0.71],
#        [0.51, 0.49],
#        [0.8 , 0.2 ],
#        [0.85, 0.15],
#        [0.76, 0.24],
#        [0.4 , 0.6 ],
#        [0.08, 0.92],
#        [0.01, 0.99],
#        [0.15, 0.85],
#        [0.23, 0.77],
#        [0.81, 0.19],
#        [0.  , 1.  ],
#        [0.6 , 0.4 ],
#        [0.24, 0.76],
#        [0.11, 0.89],
# ...

# %%
y_probs_positive=y_probs[:,1]

# %%
#calculate fpr ,tpr and threshold
fpr,tpr ,thresholds =roc_curve(y_test,y_probs_positive)
fpr
# Out:
# array([0.        , 0.03448276, 0.03448276, 0.03448276, 0.03448276,
#        0.03448276, 0.03448276, 0.06896552, 0.06896552, 0.06896552,
#        0.10344828, 0.10344828, 0.13793103, 0.13793103, 0.13793103,
#        0.20689655, 0.20689655, 0.20689655, 0.27586207, 0.37931034,
#        0.37931034, 0.48275862, 0.48275862, 0.55172414, 0.55172414,
#        1.        ])

# %%
#creating a function for ploting
import matplotlib.pyplot as plt
def plot_roc_curve(fpr,tpr):
    #plot roc
    plt.plot(fpr,tpr,color="orange",label="ROC")
    #plot line with no prediction power (baseline)
    plt.plot([0,1],[0,1],color="darkblue",linestyle="--",label="guesing")

    #customise the plot
    plt.xlabel("false positive rate ")
    plt.ylabel("true positive rate")
    plt.title("recivers operating characterstics (roc) curve")
    plt.legend()
    plt.show()
plot_roc_curve(fpr,tpr)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_probs_positive)
# Out:
# np.float64(0.8669181034482759)

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_test)
plot_roc_curve(fpr,tpr)

# %%
roc_auc_score(y_test,y_test)
#this is the perfect auc score
# Out:
# np.float64(1.0)

# %%
#how to install dirctly from jupyer noebook
import sys
# !conda install --yes --prefix {sys.prefix} seaborn
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# # All requested packages already installed.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %% [markdown]
# ### confusion matrix
# a confusion matrix is a quick way to compare the labels a model predicts and the actual labels is was supposed to predict
# in essence giving you an idea of where the model is getting confused

# %%
from sklearn.metrics import confusion_matrix
y_preds=clf.predict(x_test)
confusion_matrix(y_test,y_preds)
# Out:
# array([[23,  6],
#        [ 6, 26]])

# %%
#visalize confusion matrix with pd.crosstab()
pd.crosstab(y_test,
           y_preds,
           rownames=["Actual label"],
           colnames=["predicted labels"])
# Out:
# predicted labels   0   1
# Actual label
# 0                 23   6
# 1                  6  26

# %%
import seaborn as sns
#set the font scale
sns.set(font_scale=1.5)
#create a confusion matrix
conf_mat=confusion_matrix(y_test,y_preds)

#plot it using seaborn
sns.heatmap(conf_mat);

# %%
import sklearn
sklearn.__version__
# Out:
# '1.6.1'

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(estimator=clf,X=x,y=y)

# %%
ConfusionMatrixDisplay.from_predictions(y_true=y_test,y_pred=y_preds);

# %% [markdown]
# ## classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        29
#            1       0.81      0.81      0.81        32
#
#     accuracy                           0.80        61
#    macro avg       0.80      0.80      0.80        61
# weighted avg       0.80      0.80      0.80        61

# %%
#where precision and recall become valualbe 
disease_true=np.zeros(10000)
disease_true[1]=1
disease_preds=np.zeros(10000)
pd.DataFrame(classification_report(disease_true,
                                  disease_preds,
                                  output_dict=True))
# Out:
# C:\Users\saksh\OneDrive\Desktop\sample_project_1\env\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\saksh\OneDrive\Desktop\sample_project_1\env\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\saksh\OneDrive\Desktop\sample_project_1\env\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## 4.2.2 Regression model evaluation metrics
# the ones we are going to cover are:
# 1. R*r or coefficient of determination
# 2. mean absolute error(mae)
# 3. mean squared error

# %%
from sklearn.ensemble import RandomForestRegressor
np.random.seed(42)
x=housing_df.drop("target",axis=1)
y=housing_df["target"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=RandomForestRegressor()
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(x_train,y_train)
# Out:
# 0.9736861165621588

# %%
from sklearn.metrics import r2_score
# fill an array with y test mean
y_test_mean=np.full(len(y_test),y_test.mean())

# %%
y_test_mean[:10]
# Out:
# array([2.0550031, 2.0550031, 2.0550031, 2.0550031, 2.0550031, 2.0550031,
#        2.0550031, 2.0550031, 2.0550031, 2.0550031])

# %% [markdown]
# ##

# %%
r2_score(y_true=y_test,
        y_pred=y_test)
# Out:
# 1.0

# %%
r2_score(y_true=y_test,
        y_pred=y_test_mean)
# Out:
# 0.0

# %% [markdown]
# ### Mean absolute error (MAE)
# MAE is the average of the absolute differences between predictions and actual values.
#
# It gives you an idea of how wrong your models predictions are.

# %%
# MAE
from sklearn.metrics import mean_absolute_error

y_preds = model.predict(x_test)
mae = mean_absolute_error(y_test, y_preds)
mae
# Out:
# 0.32656738464147306

# %%
df = pd.DataFrame(data={"actual values": y_test,
                        "predicted values": y_preds})
df["differences"] = df["predicted values"] - df["actual values"]
df.head(10)
# Out:
#        actual values  predicted values  differences
# 20046        0.47700          0.493900     0.016900
# 3024         0.45800          0.754940     0.296940
# 15663        5.00001          4.928596    -0.071414
# 20484        2.18600          2.540240     0.354240
# 9814         2.78000          2.331760    -0.448240
# 13311        1.58700          1.660220     0.073220
# 7113         1.98200          2.343100     0.361100
# 7668         1.57500          1.663110     0.088110
# 18246        3.40000          2.474890    -0.925110
# 5723         4.46600          4.834478     0.368478

# %%
# MAE using formulas and differences
np.abs(df["differences"]).mean()
# Out:
# np.float64(0.32656738464147306)

# %% [markdown]
# ### Mean squared error (MSE)
#
# MSE is the mean of the square of the errors between actual and predicted values.

# %%
# Mean squared error
from sklearn.metrics import mean_squared_error

y_preds = model.predict(x_test)
mse = mean_squared_error(y_test, y_preds)
mse
# Out:
# 0.25336408094921037

# %%
df["squared_differences"] = np.square(df["differences"])
df.head()
# Out:
#        actual values  predicted values  differences  squared_differences
# 20046        0.47700          0.493900     0.016900             0.000286
# 3024         0.45800          0.754940     0.296940             0.088173
# 15663        5.00001          4.928596    -0.071414             0.005100
# 20484        2.18600          2.540240     0.354240             0.125486
# 9814         2.78000          2.331760    -0.448240             0.200919

# %%
# Calculate MSE by hand
squared = np.square(df["differences"])
squared.mean()
# Out:
# np.float64(0.25336408094921037)

# %%
df_large_error = df.copy()
df_large_error.iloc[0]["squared_differences"] = 16 # increase "squared_differences" for 1 sample
# Out:
# C:\Users\saksh\AppData\Local\Temp\ipykernel_14252\3223351396.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_large_error.iloc[0]["squared_differences"] = 16 # increase "squared_differences" for 1 sample

# %%
df_large_error.head()
# Out:
#        actual values  predicted values  differences  squared_differences
# 20046        0.47700          0.493900     0.016900            16.000000
# 3024         0.45800          0.754940     0.296940             0.088173
# 15663        5.00001          4.928596    -0.071414             0.005100
# 20484        2.18600          2.540240     0.354240             0.125486
# 9814         2.78000          2.331760    -0.448240             0.200919

# %%
# Calculate MSE with large error
df_large_error["squared_differences"].mean()
# Out:
# np.float64(0.25723998075298943)

# %%
# Artificially increase error in "squared_differences" column for ~100 samples
df_large_error.iloc[1:100, 3] = 20
df_large_error
# Out:
#        actual values  predicted values  differences  squared_differences
# 20046        0.47700          0.493900     0.016900            16.000000
# 3024         0.45800          0.754940     0.296940            20.000000
# 15663        5.00001          4.928596    -0.071414            20.000000
# 20484        2.18600          2.540240     0.354240            20.000000
# 9814         2.78000          2.331760    -0.448240            20.000000
# ...              ...               ...          ...                  ...
# 15362        2.63300          2.219830    -0.413170             0.170709
# 16623        2.66800          1.947760    -0.720240             0.518746
# 18086        5.00001          4.836378    -0.163632             0.026775
# 2144         0.72300          0.717820    -0.005180             0.000027
# 3665         1.51500          1.677810     0.162810             0.026507
#
# [4128 rows x 4 columns]

# %%
# Calculate MSE with large error(s)
df_large_error["squared_differences"].mean()
# Out:
# np.float64(0.7333102979585939)
